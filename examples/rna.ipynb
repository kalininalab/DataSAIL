# %% [markdown]
# # Split an RNA dataset
#
# In this example notebook, we will discuss how to use DataSAIL to split a dataset of RNAs. We downloaded the FASTA file from the [nRC GitHub repository](https://github.com/IcarPA-TBlab/nrc/blob/master/data/ECCB2017/dataset_Rfam_6320_13classes.fasta). As always, we first import all necessary tools.

# %%
from datasail.sail import datasail

# %% [markdown]
# ### Run DataSAIL
#
# As there is no dataset to be loaded, we directly use DataSAIL to split the data into an identity-based single cold split (I1e) and a cluster-based single cold split (C1e). We define
#   - the techniques as list: I1e abd C1e
#     The e in the end is important to split the e-data.
#   - the spits as list. The values will be normalized to ratios.
#   - the names as list. Similarly to the list of split sizes, DataSAIL needs names to name the splits.
#   - the number of runs. This will determine how many different splits to compute per technique to compute.
#   - the solving algorithm for optimizing the final problem formulation.
#   - the type of the dataset in the first axis.
#   - the data as mapping from IDs to SMILES strings.
#
# For an extensive description of the arguments please refer to the according pages of the documentation.

# %%
# %%capture
e_splits, f_splits, inter_splits = datasail(
    techniques=["I1e", "C1e"],
    splits=[7, 2, 1], 
    names=["train","val", "test"], 
    runs=3, 
    solver="SCIP",
    e_type="G",
    e_data="dataset_Rfam_6320_13classes.fasta",
)
# Out:
# 2023-10-24 14:27:49,771 cdhit_est cannot optimally cluster the data. The minimal number of clusters is 6309.
# (CVXPY) Oct 24 02:28:11 PM: Your problem has 18960 variables, 1 constraints, and 0 parameters.
# (CVXPY) Oct 24 02:28:11 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 24 02:28:11 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 24 02:28:11 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Oct 24 02:28:11 PM: Compiling problem (target solver=SCIP).
# (CVXPY) Oct 24 02:28:11 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCIP
# (CVXPY) Oct 24 02:28:11 PM: Applying reduction Dcp2Cone
# (CVXPY) Oct 24 02:28:11 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 24 02:28:11 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Oct 24 02:28:11 PM: Applying reduction SCIP
# (CVXPY) Oct 24 02:28:11 PM: Finished problem compilation (took 6.064e-02 seconds).
# (CVXPY) Oct 24 02:28:11 PM: Invoking solver SCIP  to obtain a solution.
# feasible solution found by trivial heuristic after 0.0 seconds, objective value 3.164557e+02
# presolving:
#    (0.1s) running MILP presolver
#    (0.1s) MILP presolver (2 rounds): 0 aggregations, 0 fixings, 3 bound changes
# (round 1, exhaustive) 0 del vars, 0 del conss, 0 add conss, 7 chg bounds, 0 chg sides, 0 chg coeffs, 6320 upgd conss, 0 impls, 6320 clqs
#    (0.1s) probing: 51/18960 (0.3%) - 0 fixings, 0 aggregations, 0 implications, 0 bound changes
#    (0.1s) probing aborted: 50/50 successive totally useless probings
#    (0.2s) symmetry computation started: requiring (bin +, int -, cont +), (fixed: bin -, int +, cont -)
#    (1.1s) symmetry computation finished: 1500 generators found (max: 1500, log10 of symmetry group size: 4114.7)
# presolving (2 rounds: 2 fast, 2 medium, 2 exhaustive):
#  0 deleted vars, 0 deleted constraints, 1 added constraints, 7 tightened bounds, 0 added holes, 0 changed sides, 0 changed coefficients
#  0 implications, 6320 cliques
# presolved problem has 18963 variables (18960 bin, 0 int, 3 impl, 0 cont) and 6327 constraints
#    6320 constraints of type <setppc>
#       6 constraints of type <linear>
#       1 constraints of type <orbitope>
# transformed objective value is always integral (scale: 0.00105485232067511)
# Presolving Time: 1.28
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
# t 1.3s|     1 |     0 |     0 |     - | trivial|   0 |  18k|6327 |   0 |   0 |  0 |   0 |   0 |-4.000000e+00 | 1.600000e+01 |    Inf | unknown
# p 1.8s|     1 |     0 |     3 |     - |  clique|   0 |  18k|6327 |6326 |   0 |  0 |   0 |   0 |-4.000000e+00 | 4.000000e+00 |    Inf | unknown
# p 2.0s|     1 |     0 |     6 |     - |   locks|   0 |  18k|6327 |6326 |   0 |  0 |   0 |   0 |-4.000000e+00 | 3.666667e+00 |    Inf | unknown
# *44.5s|     1 |     0 |  4256 |     - |    LP  |   0 |  18k|6328 |6326 |   0 |  0 |  13 |   0 | 0.000000e+00 | 0.000000e+00 |   0.00%| unknown
#  44.5s|     1 |     0 |  4256 |     - |  2564M |   0 |  18k|6328 |6326 |   0 |  0 |  13 |   0 | 0.000000e+00 | 0.000000e+00 | (CVXPY) Oct 24 02:28:57 PM: Problem status: optimal
#   0.00%| unknown
#
# SCIP Status        : problem is solved [optimal solution found]
# Solving Time (sec) : 44.46
# Solving Nodes      : 1
# Primal Bound       : +0.00000000000000e+00 (5 solutions)
# Dual Bound         : +0.00000000000000e+00
# Gap                : 0.00 %
# (CVXPY) Oct 24 02:28:57 PM: Optimal value: 0.000e+00
# (CVXPY) Oct 24 02:28:57 PM: Compilation took 6.064e-02 seconds
# (CVXPY) Oct 24 02:28:57 PM: Solver (including time spent in interface) took 4.606e+01 seconds
# (CVXPY) Oct 24 02:28:57 PM: Your problem has 1375 variables, 1229 constraints, and 0 parameters.
# (CVXPY) Oct 24 02:28:58 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 24 02:28:58 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 24 02:28:58 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Oct 24 02:28:58 PM: Compiling problem (target solver=SCIP).
# (CVXPY) Oct 24 02:28:58 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCIP
# (CVXPY) Oct 24 02:28:58 PM: Applying reduction Dcp2Cone
# (CVXPY) Oct 24 02:28:58 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 24 02:28:58 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Oct 24 02:28:59 PM: Applying reduction SCIP
# (CVXPY) Oct 24 02:28:59 PM: Finished problem compilation (took 1.554e+00 seconds).
# (CVXPY) Oct 24 02:28:59 PM: Invoking solver SCIP  to obtain a solution.
# presolving:
# (round 1, fast)       1228 del vars, 1226 del conss, 0 add conss, 2451 chg bounds, 0 chg sides, 3 chg coeffs, 0 upgd conss, 0 impls, 49 clqs
# (round 2, fast)       1230 del vars, 1306 del conss, 0 add conss, 2451 chg bounds, 0 chg sides, 3 chg coeffs, 0 upgd conss, 0 impls, 117 clqs
# (round 3, fast)       1260 del vars, 1336 del conss, 0 add conss, 2451 chg bounds, 0 chg sides, 3 chg coeffs, 0 upgd conss, 0 impls, 87 clqs
#    (0.0s) running MILP presolver
#    (0.0s) MILP presolver found nothing
# (round 4, exhaustive) 1260 del vars, 1336 del conss, 0 add conss, 2451 chg bounds, 0 chg sides, 3 chg coeffs, 3617 upgd conss, 0 impls, 87 clqs
#    (0.0s) probing: 51/1342 (3.8%) - 0 fixings, 0 aggregations, 0 implications, 0 bound changes
#    (0.0s) probing aborted: 50/50 successive totally useless probings
#    (0.0s) symmetry computation started: requiring (bin +, int -, cont +), (fixed: bin -, int +, cont -)
#    (0.0s) no symmetry present
# presolving (5 rounds: 5 fast, 2 medium, 2 exhaustive):
#  1260 deleted vars, 1336 deleted constraints, 0 added constraints, 2451 tightened bounds, 0 added holes, 0 changed sides, 3 changed coefficients
#  0 implications, 87 cliques
# presolved problem has 1342 variables (1342 bin, 0 int, 0 impl, 0 cont) and 3617 constraints
#       2 constraints of type <knapsack>
#      87 constraints of type <setppc>
#    3528 constraints of type <logicor>
# transformed objective value is always integral (scale: 1)
# Presolving Time: 0.03
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#   0.1s|     1 |     0 |   515 |     - |    25M |   0 |1342 |3641 |3617 |   0 |  0 |  24 |   0 | 3.163390e+01 |      --      |    Inf | unknown
#   0.4s|     1 |     0 |  4434 |     - |    29M |   0 |1342 |3842 |3623 |   6 |  1 |  25 |   0 | 3.329155e+01 |      --      |    Inf | unknown
#   0.5s|     1 |     0 |  4578 |     - |    31M |   0 |1342 |3843 |3631 |  14 |  2 |  26 |   0 | 3.505612e+01 |      --      |    Inf | unknown
#   0.5s|     1 |     0 |  4749 |     - |    32M |   0 |1342 |3843 |3639 |  22 |  3 |  26 |   0 | 3.692524e+01 |      --      |    Inf | unknown
#   0.6s|     1 |     0 |  4847 |     - |    36M |   0 |1342 |3843 |3643 |  26 |  4 |  26 |   0 | 3.778307e+01 |      --      |    Inf | unknown
#   1.1s|     1 |     0 |  6093 |     - |    53M |   0 |1342 |3867 |3700 |  84 | 20 |  54 |   0 | 4.127233e+01 | 2.690000e+02 | 551.77%| unknown
#   1.1s|     1 |     0 |  6114 |     - |    53M |   0 |1342 |3866 |3704 |  88 | 21 |  57 |   0 | 4.127508e+01 | 2.690000e+02 | 551.72%| unknown
#   1.1s|     1 |     0 |  6129 |     - |    53M |   0 |1342 |3865 |3706 |  90 | 22 |  57 |   0 | 4.127584e+01 | 2.690000e+02 | 551.71%| unknown
#   1.1s|     1 |     0 |  6131 |     - |    53M |   0 |1342 |3863 |3707 |  91 | 23 |  57 |   0 | 4.127585e+01 | 2.690000e+02 | 551.71%| unknown
#   1.2s|     1 |     0 |  6147 |     - |    53M |   0 |1342 |3863 |3706 |  92 | 24 |  58 |   0 | 4.128957e+01 | 2.690000e+02 | 551.50%| unknown
#   3.4s|     1 |     2 |  6773 |     - |    53M |   0 |1342 |3875 |3706 |  92 | 26 |  78 |  17 | 5.260219e+01 | 2.690000e+02 | 411.39%| unknown
# r11.5s|     7 |     6 |  9661 | 585.7 |rounding|   6 |1342 |3865 |3688 |  92 |  0 |  78 | 118 | 5.260219e+01 | 2.350000e+02 | 346.75%| unknown
# i11.9s|     7 |     6 |  9667 | 586.7 |  oneopt|   6 |1342 |3866 |3688 |  92 |  1 |  79 | 125 | 5.260219e+01 | 1.4(CVXPY) Oct 24 02:29:25 PM: Problem status: optimal
# 30000e+02 | 171.85%| unknown
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
# r18.4s|    36 |    21 | 24791 | 532.7 |shifting|  20 |1342 |3914 |3695 | 101 |  0 | 129 | 231 | 6.371194e+01 | 1.430000e+02 | 124.45%|  15.22%
#  20.8s|   100 |    21 | 42010 | 362.3 |    56M |  29 |1342 |3922 |3688 | 102 |  0 | 137 | 244 | 7.684632e+01 | 1.430000e+02 |  86.09%|  18.83%
# *25.1s|   181 |     0 | 70881 | 359.6 |    LP  |  31 |1342 |3867 |3691 | 124 |  1 | 158 | 270 | 9.700000e+01 | 9.700000e+01 |   0.00%|  99.43%
#
# SCIP Status        : problem is solved [optimal solution found]
# Solving Time (sec) : 25.13
# Solving Nodes      : 181
# Primal Bound       : +9.70000000000000e+01 (9 solutions)
# Dual Bound         : +9.70000000000000e+01
# Gap                : 0.00 %
# (CVXPY) Oct 24 02:29:25 PM: Optimal value: 9.700e+01
# (CVXPY) Oct 24 02:29:25 PM: Compilation took 1.554e+00 seconds
# (CVXPY) Oct 24 02:29:25 PM: Solver (including time spent in interface) took 2.540e+01 seconds
# (CVXPY) Oct 24 02:29:25 PM: Your problem has 18960 variables, 1 constraints, and 0 parameters.
# (CVXPY) Oct 24 02:29:25 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 24 02:29:25 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 24 02:29:25 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Oct 24 02:29:25 PM: Compiling problem (target solver=SCIP).
# (CVXPY) Oct 24 02:29:25 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCIP
# (CVXPY) Oct 24 02:29:25 PM: Applying reduction Dcp2Cone
# (CVXPY) Oct 24 02:29:25 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 24 02:29:25 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Oct 24 02:29:25 PM: Applying reduction SCIP
# (CVXPY) Oct 24 02:29:25 PM: Finished problem compilation (took 2.281e-02 seconds).
# (CVXPY) Oct 24 02:29:25 PM: Invoking solver SCIP  to obtain a solution.
# feasible solution found by trivial heuristic after 0.0 seconds, objective value 3.164557e+02
# presolving:
# (CVXPY) Oct 24 02:30:10 PM: Problem status: optimal
#    (0.1s) running MILP presolver
#    (0.1s) MILP presolver (2 rounds): 0 aggregations, 0 fixings, 3 bound changes
# (round 1, exhaustive) 0 del vars, 0 del conss, 0 add conss, 7 chg bounds, 0 chg sides, 0 chg coeffs, 6320 upgd conss, 0 impls, 6320 clqs
#    (0.1s) probing: 51/18960 (0.3%) - 0 fixings, 0 aggregations, 0 implications, 0 bound changes
#    (0.1s) probing aborted: 50/50 successive totally useless probings
#    (0.1s) symmetry computation started: requiring (bin +, int -, cont +), (fixed: bin -, int +, cont -)
#    (1.1s) symmetry computation finished: 1500 generators found (max: 1500, log10 of symmetry group size: 4114.7)
# presolving (2 rounds: 2 fast, 2 medium, 2 exhaustive):
#  0 deleted vars, 0 deleted constraints, 1 added constraints, 7 tightened bounds, 0 added holes, 0 changed sides, 0 changed coefficients
#  0 implications, 6320 cliques
# presolved problem has 18963 variables (18960 bin, 0 int, 3 impl, 0 cont) and 6327 constraints
#    6320 constraints of type <setppc>
#       6 constraints of type <linear>
#       1 constraints of type <orbitope>
# transformed objective value is always integral (scale: 0.00105485232067511)
# Presolving Time: 1.23
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
# t 1.3s|     1 |     0 |     0 |     - | trivial|   0 |  18k|6327 |   0 |   0 |  0 |   0 |   0 |-4.000000e+00 | 1.600000e+01 |    Inf | unknown
# p 1.7s|     1 |     0 |     3 |     - |  clique|   0 |  18k|6327 |6326 |   0 |  0 |   0 |   0 |-4.000000e+00 | 4.000000e+00 |    Inf | unknown
# p 2.0s|     1 |     0 |     6 |     - |   locks|   0 |  18k|6327 |6326 |   0 |  0 |   0 |   0 |-4.000000e+00 | 3.666667e+00 |    Inf | unknown
# *43.3s|     1 |     0 |  4256 |     - |    LP  |   0 |  18k|6328 |6326 |   0 |  0 |  13 |   0 | 0.000000e+00 | 0.000000e+00 |   0.00%| unknown
#  43.3s|     1 |     0 |  4256 |     - |  2564M |   0 |  18k|6328 |6326 |   0 |  0 |  13 |   0 | 0.000000e+00 | 0.000000e+00 |   0.00%| unknown
#
# SCIP Status        : problem is solved [optimal solution found]
# Solving Time (sec) : 43.33
# Solving Nodes      : 1
# Primal Bound       : +0.00000000000000e+00 (5 solutions)
# Dual Bound         : +0.00000000000000e+00
# Gap                : 0.00 %
# (CVXPY) Oct 24 02:30:10 PM: Optimal value: 0.000e+00
# (CVXPY) Oct 24 02:30:10 PM: Compilation took 2.281e-02 seconds
# (CVXPY) Oct 24 02:30:10 PM: Solver (including time spent in interface) took 4.490e+01 seconds
# (CVXPY) Oct 24 02:30:10 PM: Your problem has 1375 variables, 1229 constraints, and 0 parameters.
# (CVXPY) Oct 24 02:30:10 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 24 02:30:10 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 24 02:30:10 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Oct 24 02:30:10 PM: Compiling problem (target solver=SCIP).
# (CVXPY) Oct 24 02:30:10 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCIP
# (CVXPY) Oct 24 02:30:10 PM: Applying reduction Dcp2Cone
# (CVXPY) Oct 24 02:30:11 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 24 02:30:11 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Oct 24 02:30:11 PM: Applying reduction SCIP
# (CVXPY) Oct 24 02:30:12 PM: Finished problem compilation (took 1.532e+00 seconds).
# (CVXPY) Oct 24 02:30:12 PM: Invoking solver SCIP  to obtain a solution.
# presolving:
# (round 1, fast)       1228 del vars, 1226 del conss, 0 add conss, 2451 chg bounds, 0 chg sides, 3 chg coeffs, 0 upgd conss, 0 impls, 49 clqs
# (round 2, fast)       1230 del vars, 1307 del conss, 0 add conss, 2451 chg bounds, 0 chg sides, 3 chg coeffs, 0 upgd conss, 0 impls, 116 clqs
# (round 3, fast)       1261 del vars, 1338 del conss, 0 add conss, 2451 chg bounds, 0 chg sides, 3 chg coeffs, 0 upgd conss, 0 impls, 85 clqs
#    (0.0s) running MILP presolver
#    (0.0s) MILP presolver found nothing
# (round 4, exhaustive) 1261 del vars, 1338 del conss, 0 add conss, 2451 chg bounds, 0 chg sides, 3 chg coeffs, 3615 upgd conss, 0 impls, 85 clqs
#    (0.0s) probing: 51/1341 (3.8%) - 0 fixings, 0 aggregations, 0 implications, 0 bound changes
#    (0.0s) probing aborted: 50/50 successive totally useless probings
#    (0.0s) symmetry computation started: requiring (bin +, int -, cont +), (fixed: bin -, int +, cont -)
#    (0.0s) no symmetry present
# presolving (5 rounds: 5 fast, 2 medium, 2 exhaustive):
#  1261 d(CVXPY) Oct 24 02:30:29 PM: Problem status: optimal
# eleted vars, 1338 deleted constraints, 0 added constraints, 2451 tightened bounds, 0 added holes, 0 changed sides, 3 changed coefficients
#  0 implications, 85 cliques
# presolved problem has 1341 variables (1341 bin, 0 int, 0 impl, 0 cont) and 3615 constraints
#       2 constraints of type <knapsack>
#      85 constraints of type <setppc>
#    3528 constraints of type <logicor>
# transformed objective value is always integral (scale: 1)
# Presolving Time: 0.03
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#   0.1s|     1 |     0 |   583 |     - |    25M |   0 |1341 |3621 |3615 |   0 |  0 |   6 |   0 | 3.182189e+01 |      --      |    Inf | unknown
#   0.4s|     1 |     0 |  4005 |     - |    28M |   0 |1341 |3821 |3620 |   5 |  1 |   6 |   0 | 3.310432e+01 |      --      |    Inf | unknown
#   0.4s|     1 |     0 |  4101 |     - |    29M |   0 |1341 |3825 |3626 |  11 |  2 |  10 |   0 | 3.471577e+01 |      --      |    Inf | unknown
#   0.5s|     1 |     0 |  4239 |     - |    31M |   0 |1341 |3825 |3633 |  18 |  3 |  10 |   0 | 3.628601e+01 |      --      |    Inf | unknown
#   0.5s|     1 |     0 |  4329 |     - |    35M |   0 |1341 |3825 |3637 |  22 |  4 |  10 |   0 | 3.741109e+01 |      --      |    Inf | unknown
#   0.5s|     1 |     0 |  4393 |     - |    36M |   0 |1341 |3825 |3639 |  24 |  5 |  10 |   0 | 3.797798e+01 |      --      |    Inf | unknown
#   0.6s|     1 |     0 |  4469 |     - |    37M |   0 |1341 |3825 |3641 |  26 |  6 |  10 |   0 | 3.831891e+01 |      --      |    Inf | unknown
#   0.6s|     1 |     0 |  4536 |     - |    39M |   0 |1341 |3826 |3644 |  29 |  7 |  11 |   0 | 3.876133e+01 |      --      |    Inf | unknown
#   0.6s|     1 |     0 |  4637 |     - |    41M |   0 |1341 |3831 |3647 |  32 |  8 |  16 |   0 | 3.908821e+01 |      --      |    Inf | unknown
#   0.7s|     1 |     0 |  4802 |     - |    44M |   0 |1341 |3831 |3652 |  37 |  9 |  16 |   0 | 3.999818e+01 |      --      |    Inf | unknown
#   0.7s|     1 |     0 |  4894 |     - |    46M |   0 |1341 |3831 |3655 |  40 | 10 |  16 |   0 | 4.045616e+01 |      --      |    Inf | unknown
#   0.8s|     1 |     0 |  4984 |     - |    46M |   0 |1341 |3837 |3657 |  42 | 11 |  22 |   0 | 4.060498e+01 |      --      |    Inf | unknown
#   0.8s|     1 |     0 |  5049 |     - |    47M |   0 |1341 |3838 |3661 |  46 | 12 |  23 |   0 | 4.076896e+01 |      --      |    Inf | unknown
#   0.8s|     1 |     0 |  5127 |     - |    47M |   0 |1341 |3839 |3665 |  50 | 13 |  24 |   0 | 4.093439e+01 |      --      |    Inf | unknown
#   0.8s|     1 |     0 |  5175 |     - |    48M |   0 |1341 |3840 |3668 |  53 | 14 |  25 |   0 | 4.101982e+01 |      --      |    Inf | unknown
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#   0

#
# SCIP Status        : problem is solved [optimal solution found]
# Solving Time (sec) : 17.14
# Solving Nodes      : 67
# Primal Bound       : +9.70000000000000e+01 (11 solutions)
# Dual Bound         : +9.70000000000000e+01
# Gap                : 0.00 %
# (CVXPY) Oct 24 02:30:29 PM: Optimal value: 9.700e+01
# (CVXPY) Oct 24 02:30:29 PM: Compilation took 1.532e+00 seconds
# (CVXPY) Oct 24 02:30:29 PM: Solver (including time spent in interface) took 1.736e+01 seconds
# (CVXPY) Oct 24 02:30:29 PM: Your problem has 18960 variables, 1 constraints, and 0 parameters.
# (CVXPY) Oct 24 02:30:29 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 24 02:30:29 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 24 02:30:29 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Oct 24 02:30:29 PM: Compiling problem (target solver=SCIP).
# (CVXPY) Oct 24 02:30:29 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCIP
# (CVXPY) Oct 24 02:30:29 PM: Applying reduction Dcp2Cone
# (CVXPY) Oct 24 02:30:29 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 24 02:30:29 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Oct 24 02:30:29 PM: Applying reduction SCIP
# (CVXPY) Oct 24 02:30:29 PM: Finished problem compilation (took 2.485e-02 seconds).
# (CVXPY) Oct 24 02:30:29 PM: Invoking solver SCIP  to obtain a solution.
# feasible solution found by trivial heuristic after 0.0 seconds, objective value 3.164557e+02
# presolving:
#    (0.1s) running MILP presolver
#    (0.1s) MILP presolver (2 rounds): 0 aggregations, 0 fixings, 3 bound changes
# (round 1, exhaustive) 0 del vars, 0 del conss, 0 add conss, 7 chg bounds, 0 chg sides, 0 chg coeffs, 6320 upgd conss, 0 impls, 6320 clqs
#    (0.1s) probing: 51/18960 (0.3%) - 0 fixings, 0 aggregations, 0 implications, 0 bound changes
#    (0.1s) probing aborted: 50/50 successive totally useless probings
#    (0.1s) symmetry computation started: requiring (bin +, int -, cont +), (fixed: bin -, int +, cont -)
#    (1.1s) symmetry computation finished: 1500 generators found (max: 1500, log10 of symmetry group size: 4114.7)
# presolving (2 rounds: 2 fast, 2 medium, 2 exhaustive):
#  0 deleted vars, 0 deleted constraints, 1 added constraints, 7 tightened bounds, 0 added holes, 0 changed sides, 0 changed coefficients
#  0 implications, 6320 cliques
# presolved problem has 18963 variables (18960 bin, 0 int, 3 impl, 0 cont) and 6327 constraints
#    6320 constraints of type <setppc>
#       6 constraints of type <linear>
#       1 constraints of type <orbitope>
# transformed objective value is always integral (scale: 0.00105485232067511)
# Presolving Time: 1.23
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
# t 1.3s|     1 |     0 |     0 |     - | trivial|   0 |  18k|6327 |   0 |   0 |  0 |   0 |   0 |-4.000000e+00 | 1.600000e+01 |    Inf | unknown
# p 1.7s|     1 |     0 |     3 |     - |  clique|   0 |  18k|6327 |6326 |   0 |  0 |   0 |   0 |-4.000000e+00 | 4.000000e+00 |    Inf | unknown
# p 2.0s|     1 |     0 |     6 |     - |   locks|   0 |  18k|6327 |6326 |   0 |  0 |   0 |   0 |-4.000000e+00 | 3.666667e+00 |    Inf | unknown
# *43.1s|     1 |     0 |  4256 |     - |    LP  |   0 |  18k|6328 |6326 |   0 |  0 |  13 |   0 | 0.000000e+00 | 0.000000e+00 |   0.00%| unknown
#  43.1s|     1 |     0 |  4256 |     - |  2564M |   0 |  18k|6328 |6326 |   0 |  0 |  13 |   0 | 0.000000e+00 | 0.000000e+00 | (CVXPY) Oct 24 02:31:14 PM: Problem status: optimal
#   0.00%| unknown
#
# SCIP Status        : problem is solved [optimal solution found]
# Solving Time (sec) : 43.05
# Solving Nodes      : 1
# Primal Bound       : +0.00000000000000e+00 (5 solutions)
# Dual Bound         : +0.00000000000000e+00
# Gap                : 0.00 %
# (CVXPY) Oct 24 02:31:14 PM: Optimal value: 0.000e+00
# (CVXPY) Oct 24 02:31:14 PM: Compilation took 2.485e-02 seconds
# (CVXPY) Oct 24 02:31:14 PM: Solver (including time spent in interface) took 4.463e+01 seconds
# (CVXPY) Oct 24 02:31:14 PM: Your problem has 1375 variables, 1229 constraints, and 0 parameters.
# (CVXPY) Oct 24 02:31:14 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 24 02:31:14 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 24 02:31:14 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Oct 24 02:31:15 PM: Compiling problem (target solver=SCIP).
# (CVXPY) Oct 24 02:31:15 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCIP
# (CVXPY) Oct 24 02:31:15 PM: Applying reduction Dcp2Cone
# (CVXPY) Oct 24 02:31:15 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 24 02:31:15 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Oct 24 02:31:16 PM: Applying reduction SCIP
# (CVXPY) Oct 24 02:31:16 PM: Finished problem compilation (took 1.517e+00 seconds).
# (CVXPY) Oct 24 02:31:16 PM: Invoking solver SCIP  to obtain a solution.
# presolving:
# (CVXPY) Oct 24 02:31:33 PM: Problem status: optimal
# (round 1, fast)       1228 del vars, 1226 del conss, 0 add conss, 2451 chg bounds, 0 chg sides, 3 chg coeffs, 0 upgd conss, 0 impls, 49 clqs
# (round 2, fast)       1230 del vars, 1305 del conss, 0 add conss, 2451 chg bounds, 0 chg sides, 3 chg coeffs, 0 upgd conss, 0 impls, 118 clqs
# (round 3, fast)       1259 del vars, 1334 del conss, 0 add conss, 2451 chg bounds, 0 chg sides, 3 chg coeffs, 0 upgd conss, 0 impls, 89 clqs
#    (0.0s) running MILP presolver
#    (0.0s) MILP presolver found nothing
# (round 4, exhaustive) 1259 del vars, 1334 del conss, 0 add conss, 2451 chg bounds, 0 chg sides, 3 chg coeffs, 3619 upgd conss, 0 impls, 89 clqs
#    (0.0s) probing: 51/1343 (3.8%) - 0 fixings, 0 aggregations, 0 implications, 0 bound changes
#    (0.0s) probing aborted: 50/50 successive totally useless probings
#    (0.0s) symmetry computation started: requiring (bin +, int -, cont +), (fixed: bin -, int +, cont -)
#    (0.0s) no symmetry present
# presolving (5 rounds: 5 fast, 2 medium, 2 exhaustive):
#  1259 deleted vars, 1334 deleted constraints, 0 added constraints, 2451 tightened bounds, 0 added holes, 0 changed sides, 3 changed coefficients
#  0 implications, 89 cliques
# presolved problem has 1343 variables (1343 bin, 0 int, 0 impl, 0 cont) and 3619 constraints
#       2 constraints of type <knapsack>
#      89 constraints of type <setppc>
#    3528 constraints of type <logicor>
# transformed objective value is always integral (scale: 1)
# Presolving Time: 0.03
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#   0.1s|     1 |     0 |   586 |     - |    25M |   0 |1343 |3628 |3619 |   0 |  0 |   9 |   0 | 3.144592e+01 |      --      |    Inf | unknown
# r 0.1s|     1 |     0 |   586 |     - |shifting|   0 |1343 |3628 |3619 |   0 |  0 |   9 |   0 | 3.144592e+01 | 1.128000e+03 |3487.11%| unknown
#   0.1s|     1 |     0 |   711 |     - |    28M |   0 |1343 |3628 |3624 |   5 |  1 |   9 |   0 | 3.273811e+01 | 1.128000e+03 |3345.53%| unknown
# i 0.1s|     1 |     0 |   711 |     - |  oneopt|   0 |1343 |3628 |3624 |   5 |  1 |   9 |   0 | 3.273811e+01 | 4.160000e+02 |1170.69%| unknown
#   0.1s|     1 |     0 |   856 |     - |    29M |   0 |1343 |3628 |3631 |  12 |  2 |   9 |   0 | 3.464973e+01 | 4.160000e+02 |1100.59%| unknown
#   0.2s|     1 |     0 |  1008 |     - |    32M |   0 |1343 |3629 |3639 |  20 |  3 |  10 |   0 | 3.639724e+01 | 4.160000e+02 |1042.94%| unknown
#   0.2s|     1 |     0 |  1126 |     - |    33M |   0 |1343 |3629 |3643 |  24 |  4 |  10 |   0 | 3.743884e+01 | 4.160000e+02 |1011.15%| unknown
#   0.7s|     1 |     0 |  2119 |     - |    52M |   0 |1343 |3663 |3692 |  76 | 22 |  44 |   0 | 4.065440e+01 | 4.160000e+02 | 923.26%| unknown
#   0.7s|     1 |     0 |  2124 |     - |    52M |   0 |1343 |3663 |3693 |  77 | 23 |  44 |   0 | 4.065446e+01 | 4.160000e+02 | 923.26%| unknown
#   0.7s|     1 |     0 |  2154 |     - |    52M |   0 |1343 |3662 |3694 |  78 | 24 |  45 |   0 | 4.067028e+01 | 4.160000e+02 | 922.86%| unknown
#   3.9s|     1 |     2 | 11043 |     - |    53M |   0 |1343 |3660 |3694 |  78 | 26 |  51 |  20 | 5.255016e+01 | 4.160000e+02 | 691.62%| unknown
# r 6.9s|     4 |     3 | 13041 |3629.0 |rounding|   3 |1343 |3657 |3679 |  78 |  0 |  53 |  69 | 5.255016e+01 | 2.340000e+02 | 345.29%| unknown
# i 8.1s|     5 |     4 | 13041 |2721.8 |  oneopt|   4 |1343 |3657 |3679 |  78 |  0 |  53 |  98 | 5.255016e+01 | 1.430000e+02 | 172.12%| unknown
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
# *17.0s|    27 |     4 | 20507 | 705.9 |    LP  |   6 |1343 |3658 |3679 |  78 |  1 |  86 | 199 | 7.630439e+01 | 9.700000e+01 |  27.12%|  31.60%
#
# SCIP Status        : problem is solved [optimal solution found]
# Solving Time (sec) : 17.32
# Solving Nodes      : 37
# Primal Bound       : +9.70000000000000e+01 (12 solutions)
# Dual Bound         : +9.70000000000000e+01
# Gap                : 0.00 %
# (CVXPY) Oct 24 02:31:33 PM: Optimal value: 9.700e+01
# (CVXPY) Oct 24 02:31:33 PM: Compilation took 1.517e+00 seconds
# (CVXPY) Oct 24 02:31:33 PM: Solver (including time spent in interface) took 1.755e+01 seconds

# %% [markdown]
# ## The output
#
# Finally, we inspect the e_split object as this holds all the assignments of the datapoints to the splits, for each run and each technique. First, the overall architecture is described, lastly we look at the first five assignments of the C1 run 0.

# %%
print(type(e_splits))
for key in e_splits.keys():
    print(f"{key} - Type: {type(e_splits[key])} - Length: {len(e_splits[key])}")
    for run in range(len(e_splits[key])):
        print(f"\tRun {run + 1} - Type: {type(e_splits[key][run])} - {len(e_splits[key][run])} assignments")
print("\n" + "\n".join(f"ID: {idx} - Split: {split}" for idx, split in list(e_splits[key][0].items())[:5]))
# Out:
# <class 'dict'>
# I1e - Type: <class 'list'> - Length: 3
# 	Run 1 - Type: <class 'dict'> - 6320 assignments
# 	Run 2 - Type: <class 'dict'> - 6320 assignments
# 	Run 3 - Type: <class 'dict'> - 6320 assignments
# C1e - Type: <class 'list'> - Length: 3
# 	Run 1 - Type: <class 'dict'> - 6320 assignments
# 	Run 2 - Type: <class 'dict'> - 6320 assignments
# 	Run 3 - Type: <class 'dict'> - 6320 assignments
#
# ID: RF00001_AF095839_1_346-228_5S_rRNA - Split: train
# ID: RF00001_AY245018_1_1-119_5S_rRNA - Split: val
# ID: RF00001_X52048_1_2-120_5S_rRNA - Split: train
# ID: RF00001_M28193_1_1-119_5S_rRNA - Split: val
# ID: RF00001_X14816_1_860-978_5S_rRNA - Split: train
